# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#    angle  velocity  position
# 0    0.0   -0.0654  -0.00218
# 1    0.0    0.0000  -0.00218
# 2    0.0   -0.0654  -0.00436
# 3    0.0    0.0000  -0.00436
# 4    0.0   -0.0654  -0.00654

# %%
fig = px.line(df[:-5])
fig.show()
